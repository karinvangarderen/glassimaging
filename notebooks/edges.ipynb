# %%
base_img = #

segmentation = #

# %%
from skimage.segmentation import clear_border
from skimage.io import imread
import skimage
import matplotlib.pyplot as plt

im = imread(base_img, plugin='simpleitk')
seg = imread(segmentation, plugin='simpleitk')
seg = skimage.img_as_uint(seg)

plt.figure() 
plt.imshow(im[100,:,:], cmap='gray') 
plt.contour(seg[100,:,:], [0.5])
# Out:
# C:\Users\043413\AppData\Local\Continuum\anaconda3\envs\PyTorch\lib\site-packages\skimage\util\dtype.py:141: UserWarning: Possible precision loss when converting from float32 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
